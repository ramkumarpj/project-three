# %%
import requests
import pandas as pd
from datetime import datetime
import pprint
import json

pp = pprint.PrettyPrinter(indent=4)

# %%
# Base URL to retreive company facts from SEC Data API
base_url = "https://data.sec.gov/api/xbrl/companyfacts/"

# Headers to be set to receive appropriate respnse from SEC Data API
headers = {
    'User-Agent' : 'ramkumarpj@gmail.com',
    'Host' : 'data.sec.gov'
}

# %%
# CIK - Central Index Key - Unique key that identifies a company in SEC Database

# List of CIKs under analysis

cik_list = ['808362', '1652044', '1637459' ]

# Data elements to be explored for each CIK

data_elements = [ 'Revenues',
                      'SalesRevenueGoodsNet',
                      'SalesRevenueServicesNet',
                      'RevenueFromContractWithCustomerIncludingAssessedTax',
                      'GrossProfit',
                      'OperatingIncomeLoss',
                      'NetIncomeLoss',
                      'ResearchAndDevelopmentExpense',
                      'SellingAndMarketingExpense',
                      'ShareBasedCompensation',
                      'Depreciation',
                      'AllocatedShareBasedCompensationExpense',
                      'CostsAndExpenses',
                      'GeneralAndAdministrativeExpense',
                      'InterestExpense',
                      'LeaseAndRentalExpense',
                      'MarketingAndAdvertisingExpense',
                      'OtherAccruedLiabilitiesCurrent',
                      'EntityCommonStockSharesOutstanding',
                      'EntityPublicFloat']

# %%
def isQuarterlyOrAnnualFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month <3 or end_date.month - start_date.month == 11

def isQuarterlyFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month <3 

def isAnnualFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month == 11

# %%
def getQuarterInFiling(filing):
    
    if 'start' in filing:
        if isQuarterlyFiling(filing['start'], filing['end']):
            if filing['fp'][1] != 'Y' :
                return int(filing['fp'][1])
            else :
                return datetime.strptime(filing['end'], '%Y-%m-%d').month/3
        elif isAnnualFiling(filing['start'], filing['end']):
            return 0
    else:
        if filing['fp'][1] == 'Y':
            return 0
        else:
            return int(filing['fp'][1])

# %%
def getYearInFiling(filing):
    
    end_date = datetime.strptime(filing['end'], '%Y-%m-%d') 
    
    return end_date.year

# %%
def extractData(tenQ_tenK_filings_list, items, key):
    
         
    if key in items.keys():
        i = 1
        for key2 in items[key]['units'].keys():

            fin_list = items[key]['units'][key2]
            tenQ_tenK_filings = [i for i in fin_list if i['form'] == '10-Q' or i['form'] == '10-K']

            #print(f"{i}. {key} {key2} 10Qs- {tenQCount}, 10Ks - {tenKCount}")

            i+=1

            tenQ_tenK_filings_list.append({
                'key' : key,
                'units' : key2,
                'filings' : tenQ_tenK_filings
            })

# %%
def transformData(tenQ_tenK_filings_list, key):
    
    if len(tenQ_tenK_filings_list) > 0 :
        filings = tenQ_tenK_filings_list[0]['filings']
    
        print(f' key={key},  Length of the list {len(filings)}')

    
        tenQ_tenK_filings_indexed = {}

        # Build a dictionary with a key using start and end fields 
        for filing in filings:
            #print(filing)
            if 'start' not in filing:
                start = '-'
            else:
                start = filing['start']
            
            index = start + ':' + filing['end']
            
    
            if index in tenQ_tenK_filings_indexed :
                tenQ_tenK_filings_indexed[index].append(filing)
            else :
                tenQ_tenK_filings_indexed[index] = [filing]
                
        # Identify multiple filings for same period
        tenQ_tenK_multiple_filings = [filing for filing in tenQ_tenK_filings_indexed.values() 
                                      if len(filing) > 1]
        
        # Identify single filings for same period
        tenQ_tenK_single_filings = [filing[0] for filing in tenQ_tenK_filings_indexed.values() 
                                    if len(filing) < 2]
        
        # Sort multiple filings in descending order of filed date 
        # Append the latest filing to single filings list
        for filing in tenQ_tenK_multiple_filings:
            filing.sort(key = lambda x: 
                        datetime.strptime(x['filed'], '%Y-%m-%d'), reverse = True)
            tenQ_tenK_single_filings.append(filing[0])
 
        # Sort single filings in ascending order of end date
        tenQ_tenK_single_filings.sort(key = lambda x: datetime.strptime(x['end'], '%Y-%m-%d'))
        
        #pp.pprint(tenQ_tenK_single_filings)
        
        print(f' key={key},  Length of the list single filings {len(tenQ_tenK_single_filings)}')
        
        # Filter single filings to keep only quatery and annual filings (eliminate 6 months, 9 months filings)
        tenQ_tenK_single_filings_qtr_annnual_filtered = [filing for filing 
                                                          in tenQ_tenK_single_filings 
                                                          if 'start' in filing and isQuarterlyOrAnnualFiling(
                                                              filing['start'], filing['end'])]
        
        print(f' key={key},  Length of the list after filtering {len(tenQ_tenK_single_filings_qtr_annnual_filtered)}')
        
        if len(tenQ_tenK_single_filings_qtr_annnual_filtered) == 0:
            tenQ_tenK_single_filings_qtr_annnual_filtered = tenQ_tenK_single_filings
        
        print(f' key={key},  Length of the list final {len(tenQ_tenK_single_filings_qtr_annnual_filtered)}')

        #pp.pprint(tenQ_tenK_single_filings_qtr_annnual_filtered) 
        
        return tenQ_tenK_single_filings_qtr_annnual_filtered

# %%
# Create List of dictionaries to be imported into MongoDB Finance Collection

# { 
# 'cik' : 4949494,
# 'dataType' : 'Revenues',
# 'value' : 4949494949,
# 'qtr' : 1
# 'year' : 2018
# }
    
def getFinanceData(tenQ_tenK_filings_transformed, cik, key):
    
    finance_records = [ {'cik' : cik,
                        'dataType' : key,
                        'value' : filing['val'],
                        'qtr' : getQuarterInFiling(filing),
                        'year' : getYearInFiling(filing)
                        } for filing in tenQ_tenK_filings_transformed]

    print(f' cik={cik}, key={key},  Length of the finance record {len(finance_records)}')
    
    #pp.pprint(finance_records)
    
    return finance_records

# %%
def saveDataToFile(data, file_name):
    
    with open(file_name,'w') as fi:
        fi.write(json.dumps(data, indent=4))
    
    print(f"Completed writing to file {file_name}")

# %%
company_data = []
finance_data = []

for cik in cik_list:
    
    # Create the URL to retrieve data for specific CIK
    url = base_url + f'CIK{cik.zfill(10)}.json'

    print(url)
    
    # Fetch the data from SEC Data API
    response = requests.get(url, headers=headers).json()

    print(f"received data for company- {response['entityName']}, cik = {response['cik']}")
    company_data.append({'cik' : response['cik'],
                        'compnanyName' : response['entityName']})
    # Get DEI Items from response
    dei = response['facts']['dei']

    # Get US-GAAP Items from response
    us_gaap = response['facts']['us-gaap']
    
    for key in data_elements: 
        tenQ_tenK_filings_list = []
        extractData(tenQ_tenK_filings_list, us_gaap, key)
        extractData(tenQ_tenK_filings_list, dei, key)
        tenQ_tenK_filings_transformed = []
        tenQ_tenK_filings_transformed = transformData(tenQ_tenK_filings_list, key)
        if tenQ_tenK_filings_transformed is not None:
            finance_data.extend(getFinanceData(tenQ_tenK_filings_transformed, cik, key))
        

print(f"Length of Finance Data = {len(finance_data)}")
saveDataToFile(finance_data, "../../data/output/finance_data.json") 
saveDataToFile(company_data, "../../data/output/company_data.json")
# Out:
# https://data.sec.gov/api/xbrl/companyfacts/CIK0000808362.json
# received data for company- Baker Hughes Holdings LLC, cik = 808362
#  key=SalesRevenueGoodsNet,  Length of the list 117
#  key=SalesRevenueGoodsNet,  Length of the list single filings 61
#  key=SalesRevenueGoodsNet,  Length of the list after filtering 41
#  key=SalesRevenueGoodsNet,  Length of the list final 41
#  cik=808362, key=SalesRevenueGoodsNet,  Length of the finance record 41
#  key=SalesRevenueServicesNet,  Length of the list 117
#  key=SalesRevenueServicesNet,  Length of the list single filings 61
#  key=SalesRevenueServicesNet,  Length of the list after filtering 41
#  key=SalesRevenueServicesNet,  Length of the list final 41
#  cik=808362, key=SalesRevenueServicesNet,  Length of the finance record 41
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list 8
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list single filings 8
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list after filtering 4
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list final 4
#  cik=808362, key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the finance record 4
#  key=GrossProfit,  Length of the list 100
#  key=GrossProfit,  Length of the list single filings 55
#  key=GrossProfit,  Length of the list after filtering 55
#  key=GrossProfit,  Length of the list final 55
#  cik=808362, key=GrossProfit,  Length of the finance record 55
#  key=OperatingIncomeLoss,  Length of the list 190
#  key=OperatingIncomeLoss,  Length of the list single filings 95
#  key=OperatingIncomeLoss,  Length of the list after filtering 63
#  key=OperatingIncomeLoss,  Length of the list final 63
#  cik=808362, key=OperatingIncomeLoss,  Length of the finance record 63
#  key=NetIncomeLoss,  Length of the list 249
#  key=NetIncomeLoss,  Length of the list single filings 99
#  key=NetIncomeLoss,  Length of the list after filtering 71
#  key=NetIncomeLoss,  Length of the list final 71
#  cik=808362, key=NetIncomeLoss,  Length of the finance record 71
#  key=ResearchAndDevelopmentExpense,  Length of the list 130
#  key=ResearchAndDevelopmentExpense,  Length of the list single filings 65
#  key=ResearchAndDevelopmentExpense,  Length of the list after filtering 45
#  key=ResearchAndDevelopmentExpense,  Length of the list final 45
#  cik=808362, key=ResearchAndDevelopmentExpense,  Length of the finance record 45
#  key=ShareBasedCompensation,  Length of the list 56
#  key=ShareBasedCompensation,  Length of the list single filings 36
#  key=ShareBasedCompensation,  Length of the list after filtering 22
#  key=ShareBasedCompensation,  Length of the list final 22
#  cik=808362, key=ShareBasedCompensation,  Length of the finance record 22
#  key=Depreciation,  Length of the list 40
#  key=Depreciation,  Length of the list single filings 18
#  key=Depreciation,  Length of the list after filtering 16
#  key=Depreciation,  Length of the list final 16
#  cik=808362, key=Depreciation,  Length of the finance record 16
#  key=AllocatedShareBasedCompensationExpense,  Length of the list 15
#  key=AllocatedShareBasedCompensationExpense,  Length of the list single filings 7
#  key=AllocatedShareBasedCompensationExpense,  Length of the list after filtering 7
#  key=AllocatedShareBasedCompensationExpense,  Length of the list final 7
#  cik=808362, key=AllocatedShareBasedCompensationExpense,  Length of the finance record 7
#  key=CostsAndExpenses,  Length of the list 181
#  key=CostsAndExpenses,  Length of the list single filings 92
#  key=CostsAndExpenses,  Length of the list after filtering 60
#  key=CostsAndExpenses,  Length of the list final 60
#  cik=808362, key=CostsAndExpenses,  Length of the finance record 60
#  key=InterestExpense,  Length of the list 108
#  key=InterestExpense,  Length of the list single filings 57
#  key=InterestExpense,  Length of the list after filtering 38
#  key=InterestExpense,  Length of the list final 38
#  cik=808362, key=InterestExpense,  Length of the finance record 38
#  key=LeaseAndRentalExpense,  Length of the list 27
#  key=LeaseAndRentalExpense,  Length of the list single filings 11
#  key=LeaseAndRentalExpense,  Length of the list after filtering 11
#  key=LeaseAndRentalExpense,  Length of the list final 11
#  cik=808362, key=LeaseAndRentalExpense,  Length of the finance record 11
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list 66
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list single filings 34
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list after filtering 0
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list final 34
#  cik=808362, key=OtherAccruedLiabilitiesCurrent,  Length of the finance record 34
#  key=EntityCommonStockSharesOutstanding,  Length of the list 57
#  key=EntityCommonStockSharesOutstanding,  Length of the list single filings 57
#  key=EntityCommonStockSharesOutstanding,  Length of the list after filtering 0
#  key=EntityCommonStockSharesOutstanding,  Length of the list final 57
#  cik=808362, key=EntityCommonStockSharesOutstanding,  Length of the finance record 57
#  key=EntityPublicFloat,  Length of the list 21
#  key=EntityPublicFloat,  Length of the list single filings 15
#  key=EntityPublicFloat,  Length of the list after filtering 0
#  key=EntityPublicFloat,  Length of the list final 15
#  cik=808362, key=EntityPublicFloat,  Length of the finance record 15
# https://data.sec.gov/api/xbrl/companyfacts/CIK0001652044.json
# received data for company- Alphabet Inc., cik = 1652044
#  key=Revenues,  Length of the list 57
#  key=Revenues,  Length of the list single filings 38
#  key=Revenues,  Length of the list after filtering 27
#  key=Revenues,  Length of the list final 27
#  cik=1652044, key=Revenues,  Length of the finance record 27
#  key=OperatingIncomeLoss,  Length of the list 111
#  key=OperatingIncomeLoss,  Length of the list single filings 58
#  key=OperatingIncomeLoss,  Length of the list after filtering 39
#  key=OperatingIncomeLoss,  Length of the list final 39
#  cik=1652044, key=OperatingIncomeLoss,  Length of the finance record 39
#  key=NetIncomeLoss,  Length of the list 112
#  key=NetIncomeLoss,  Length of the list single filings 58
#  key=NetIncomeLoss,  Length of the list after filtering 39
#  key=NetIncomeLoss,  Length of the list final 39
#  cik=1652044, key=NetIncomeLoss,  Length of the finance record 39
#  key=ResearchAndDevelopmentExpense,  Length of the list 111
#  key=ResearchAndDevelopmentExpense,  Length of the list single filings 58
#  key=ResearchAndDevelopmentExpense,  Length of the list after filtering 39
#  key=ResearchAndDevelopmentExpense,  Length of the list final 39
#  cik=1652044, key=ResearchAndDevelopmentExpense,  Length of the finance record 39
#  key=SellingAndMarketingExpense,  Length of the list 111
#  key=SellingAndMarketingExpense,  Length of the list single filings 58
#  key=SellingAndMarketingExpense,  Length of the list after filtering 39
#  key=SellingAndMarketingExpense,  Length of the list final 39
#  cik=1652044, key=SellingAndMarketingExpense,  Length of the finance record 39
#  key=ShareBasedCompensation,  Length of the list 85
#  key=ShareBasedCompensation,  Length of the list single filings 45
#  key=ShareBasedCompensation,  Length of the list after filtering 26
#  key=ShareBasedCompensation,  Length of the list final 26
#  cik=1652044, key=ShareBasedCompensation,  Length of the finance record 26
#  key=Depreciation,  Length of the list 3
#  key=Depreciation,  Length of the list single filings 3
#  key=Depreciation,  Length of the list after filtering 3
#  key=Depreciation,  Length of the list final 3
#  cik=1652044, key=Depreciation,  Length of the finance record 3
#  key=AllocatedShareBasedCompensationExpense,  Length of the list 111
#  key=AllocatedShareBasedCompensationExpense,  Length of the list single filings 58
#  key=AllocatedShareBasedCompensationExpense,  Length of the list after filtering 39
#  key=AllocatedShareBasedCompensationExpense,  Length of the list final 39
#  cik=1652044, key=AllocatedShareBasedCompensationExpense,  Length of the finance record 39
#  key=CostsAndExpenses,  Length of the list 111
#  key=CostsAndExpenses,  Length of the list single filings 58
#  key=CostsAndExpenses,  Length of the list after filtering 39
#  key=CostsAndExpenses,  Length of the list final 39
#  cik=1652044, key=CostsAndExpenses,  Length of the finance record 39
#  key=GeneralAndAdministrativeExpense,  Length of the list 111
#  key=GeneralAndAdministrativeExpense,  Length of the list single filings 58
#  key=GeneralAndAdministrativeExpense,  Length of the list after filtering 39
#  key=GeneralAndAdministrativeExpense,  Length of the list final 39
#  cik=1652044, key=GeneralAndAdministrativeExpense,  Length of the finance record 39
#  key=InterestExpense,  Length of the list 111
#  key=InterestExpense,  Length of the list single filings 58
#  key=InterestExpense,  Length of the list after filtering 39
#  key=InterestExpense,  Length of the list final 39
#  cik=1652044, key=InterestExpense,  Length of the finance record 39
#  key=LeaseAndRentalExpense,  Length of the list 14
#  key=LeaseAndRentalExpense,  Length of the list single filings 6
#  key=LeaseAndRentalExpense,  Length of the list after filtering 6
#  key=LeaseAndRentalExpense,  Length of the list final 6
#  cik=1652044, key=LeaseAndRentalExpense,  Length of the finance record 6
#  key=MarketingAndAdvertisingExpense,  Length of the list 27
#  key=MarketingAndAdvertisingExpense,  Length of the list single filings 11
#  key=MarketingAndAdvertisingExpense,  Length of the list after filtering 11
#  key=MarketingAndAdvertisingExpense,  Length of the list final 11
#  cik=1652044, key=MarketingAndAdvertisingExpense,  Length of the finance record 11
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list 58
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list single filings 30
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list after filtering 0
#  key=OtherAccruedLiabilitiesCurrent,  Length of the list final 30
#  cik=1652044, key=OtherAccruedLiabilitiesCurrent,  Length of the finance record 30
#  key=EntityPublicFloat,  Length of the list 9
#  key=EntityPublicFloat,  Length of the list single filings 9
#  key=EntityPublicFloat,  Length of the list after filtering 0
#  key=EntityPublicFloat,  Length of the list final 9
#  cik=1652044, key=EntityPublicFloat,  Length of the finance record 9
# https://data.sec.gov/api/xbrl/companyfacts/CIK0001637459.json
# received data for company- Kraft Heinz Co, cik = 1637459
#  key=Revenues,  Length of the list 0
#  key=Revenues,  Length of the list single filings 0
#  key=Revenues,  Length of the list after filtering 0
#  key=Revenues,  Length of the list final 0
#  cik=1637459, key=Revenues,  Length of the finance record 0
#  key=SalesRevenueGoodsNet,  Length of the list 64
#  key=SalesRevenueGoodsNet,  Length of the list single filings 31
#  key=SalesRevenueGoodsNet,  Length of the list after filtering 17
#  key=SalesRevenueGoodsNet,  Length of the list final 17
#  cik=1637459, key=SalesRevenueGoodsNet,  Length of the finance record 17
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list 100
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list single filings 47
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list after filtering 28
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list final 28
#  cik=1637459, key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the finance record 28
#  key=GrossProfit,  Length of the list 164
#  key=GrossProfit,  Length of the list single filings 67
#  key=GrossProfit,  Length of the list after filtering 38
#  key=GrossProfit,  Length of the list final 38
#  cik=1637459, key=GrossProfit,  Length of the finance record 38
#  key=OperatingIncomeLoss,  Length of the list 124
#  key=OperatingIncomeLoss,  Length of the list single filings 61
#  key=OperatingIncomeLoss,  Length of the list after filtering 35
#  key=OperatingIncomeLoss,  Length of the list final 35
#  cik=1637459, key=OperatingIncomeLoss,  Length of the finance record 35
#  key=NetIncomeLoss,  Length of the list 140
#  key=NetIncomeLoss,  Length of the list single filings 63
#  key=NetIncomeLoss,  Length of the list after filtering 37
#  key=NetIncomeLoss,  Length of the list final 37
#  cik=1637459, key=NetIncomeLoss,  Length of the finance record 37
#  key=ResearchAndDevelopmentExpense,  Length of the list 24
#  key=ResearchAndDevelopmentExpense,  Length of the list single filings 10
#  key=ResearchAndDevelopmentExpense,  Length of the list after filtering 10
#  key=ResearchAndDevelopmentExpense,  Length of the list final 10
#  cik=1637459, key=ResearchAndDevelopmentExpense,  Length of the finance record 10
#  key=ShareBasedCompensation,  Length of the list 84
#  key=ShareBasedCompensation,  Length of the list single filings 41
#  key=ShareBasedCompensation,  Length of the list after filtering 30
#  key=ShareBasedCompensation,  Length of the list final 30
#  cik=1637459, key=ShareBasedCompensation,  Length of the finance record 30
#  key=Depreciation,  Length of the list 17
#  key=Depreciation,  Length of the list single filings 9
#  key=Depreciation,  Length of the list after filtering 9
#  key=Depreciation,  Length of the list final 9
#  cik=1637459, key=Depreciation,  Length of the finance record 9
#  key=InterestExpense,  Length of the list 124
#  key=InterestExpense,  Length of the list single filings 61
#  key=InterestExpense,  Length of the list after filtering 35
#  key=InterestExpense,  Length of the list final 35
#  cik=1637459, key=InterestExpense,  Length of the finance record 35
#  key=LeaseAndRentalExpense,  Length of the list 0
#  key=LeaseAndRentalExpense,  Length of the list single filings 0
#  key=LeaseAndRentalExpense,  Length of the list after filtering 0
#  key=LeaseAndRentalExpense,  Length of the list final 0
#  cik=1637459, key=LeaseAndRentalExpense,  Length of the finance record 0
#  key=MarketingAndAdvertisingExpense,  Length of the list 9
#  key=MarketingAndAdvertisingExpense,  Length of the list single filings 5
#  key=MarketingAndAdvertisingExpense,  Length of the list after filtering 5
#  key=MarketingAndAdvertisingExpense,  Length of the list final 5
#  cik=1637459, key=MarketingAndAdvertisingExpense,  Length of the finance record 5
#  key=EntityCommonStockSharesOutstanding,  Length of the list 35
#  key=EntityCommonStockSharesOutstanding,  Length of the list single filings 34
#  key=EntityCommonStockSharesOutstanding,  Length of the list after filtering 0
#  key=EntityCommonStockSharesOutstanding,  Length of the list final 34
#  cik=1637459, key=EntityCommonStockSharesOutstanding,  Length of the finance record 34
#  key=EntityPublicFloat,  Length of the list 9
#  key=EntityPublicFloat,  Length of the list single filings 9
#  key=EntityPublicFloat,  Length of the list after filtering 0
#  key=EntityPublicFloat,  Length of the list final 9
#  cik=1637459, key=EntityPublicFloat,  Length of the finance record 9
# Length of Finance Data = 1291
# Completed writing to file ../../data/output/finance_data.json
# Completed writing to file ../../data/output/company_data.json
