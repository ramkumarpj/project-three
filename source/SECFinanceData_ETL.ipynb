# %%
import requests
import pandas as pd
from datetime import datetime
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# Base URL to retreive company facts from SEC Data API
base_url = "https://data.sec.gov/api/xbrl/companyfacts/"

# Headers to be set to receive appropriate respnse from SEC Data API
headers = {
    'User-Agent' : 'ramkumarpj@gmail.com',
    'Host' : 'data.sec.gov'
}

# %%
# CIK - Central Index Key - Unique key that identifies a company in SEC Database

# List of CIKs under analysis

cik_list = ['808362', '1652044', '1637459' ]

# Data elements to be explored for each CIK

data_elements = [ 'Revenues',
                      'SalesRevenueGoodsNet',
                      'SalesRevenueServicesNet',
                      'RevenueFromContractWithCustomerIncludingAssessedTax',
                      'GrossProfit',
                      'OperatingIncomeLoss',
                      'NetIncomeLoss',
                      'ResearchAndDevelopmentExpense',
                      'SellingAndMarketingExpense',
                      'ShareBasedCompensation',
                      'Depreciation',
                      'AllocatedShareBasedCompensationExpense',
                      'CostsAndExpenses',
                      'GeneralAndAdministrativeExpense',
                      'InterestExpense',
                      'LeaseAndRentalExpense',
                      'MarketingAndAdvertisingExpense',
                      'OtherAccruedLiabilitiesCurrent',
                      'EntityCommonStockSharesOutstanding',
                      'EntityPublicFloat']

# %%
def isQuaterlyOrAnnualFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month <3 or end_date.month - start_date.month == 11

def isQuaterlyFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month <3 

def isAnnualFiling(start, end):

    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    
    return end_date.month - start_date.month == 11

# %%
def extractData(tenQ_tenK_filings_list, items, key):
    
         
    if key in items.keys():
        i = 1
        for key2 in items[key]['units'].keys():

            fin_list = items[key]['units'][key2]
            tenQ_tenK_filings = [i for i in fin_list if i['form'] == '10-Q' or i['form'] == '10-K']

            #print(f"{i}. {key} {key2} 10Qs- {tenQCount}, 10Ks - {tenKCount}")

            i+=1

            tenQ_tenK_filings_list.append({
                'key' : key,
                'units' : key2,
                'filings' : tenQ_tenK_filings
            })

# %%
def transformData(tenQ_tenK_filings_list, key):
    
    if len(tenQ_tenK_filings_list) > 0 :
        filings = tenQ_tenK_filings_list[0]['filings']
    
        print(f' key={key},  Length of the list {len(filings)}')

    
        tenQ_tenK_filings_indexed = {}

        # Build a dictionary with a key using start and end fields 
        for filing in filings:
            #print(filing)
            if 'start' not in filing:
                start = '-'
            else:
                start = filing['start']
            
            index = start + ':' + filing['end']
            
    
            if index in tenQ_tenK_filings_indexed :
                tenQ_tenK_filings_indexed[index].append(filing)
            else :
                tenQ_tenK_filings_indexed[index] = [filing]
                
        # Identify multiple filings for same period
        tenQ_tenK_multiple_filings = [filing for filing in tenQ_tenK_filings_indexed.values() 
                                      if len(filing) > 1]
        
        # Identify single filings for same period
        tenQ_tenK_single_filings = [filing[0] for filing in tenQ_tenK_filings_indexed.values() 
                                    if len(filing) < 2]
        
        # Sort multiple filings in descending order of filed date 
        # Append the latest filing to single filings list
        for filing in tenQ_tenK_multiple_filings:
            filing.sort(key = lambda x: 
                        datetime.strptime(x['filed'], '%Y-%m-%d'), reverse = True)
            tenQ_tenK_single_filings.append(filing[0])
 
        # Sort single filings in ascending order of end date
        tenQ_tenK_single_filings.sort(key = lambda x: datetime.strptime(x['end'], '%Y-%m-%d'))
        
        #pp.pprint(tenQ_tenK_single_filings)
        
        print(f' key={key},  Length of the list single filings {len(tenQ_tenK_single_filings)}')
        
        # Filter single filings to keep only quatery and annual filings (eliminate 6 months, 9 months filings)
        tenQ_tenK_single_filings_qtr_annnual_filtered = [filing for filing 
                                                          in tenQ_tenK_single_filings 
                                                          if 'start' in filing and isQuaterlyOrAnnualFiling(
                                                              filing['start'], filing['end'])]
        
        print(f' key={key},  Length of the list after filtering {len(tenQ_tenK_single_filings_qtr_annnual_filtered)}')
        
        if len(tenQ_tenK_single_filings_qtr_annnual_filtered) == 0:
            tenQ_tenK_single_filings_qtr_annnual_filtered = tenQ_tenK_single_filings
        
        print(f' key={key},  Length of the list final {len(tenQ_tenK_single_filings_qtr_annnual_filtered)}')

        pp.pprint(tenQ_tenK_single_filings_qtr_annnual_filtered)

# %%
for cik in cik_list:
    
    # Create the URL to retrieve data for specific CIK
    url = base_url + f'CIK{cik.zfill(10)}.json'

    print(url)
    
    # Fetch the data from SEC Data API
    response = requests.get(url, headers=headers).json()

    print(f"received data for company- {response['entityName']}, cik = {response['cik']}")
    
    # Get DEI Items from response
    dei = response['facts']['dei']

    # Get US-GAAP Items from response
    us_gaap = response['facts']['us-gaap']
    

    for key in data_elements: 
        tenQ_tenK_filings_list = []
        extractData(tenQ_tenK_filings_list, us_gaap, key)
        extractData(tenQ_tenK_filings_list, dei, key)
        transformData(tenQ_tenK_filings_list, key)
# Out:
# https://data.sec.gov/api/xbrl/companyfacts/CIK0000808362.json
# received data for company- Baker Hughes Holdings LLC, cik = 808362
#  key=SalesRevenueGoodsNet,  Length of the list 117
#  key=SalesRevenueGoodsNet,  Length of the list single filings 61
#  key=SalesRevenueGoodsNet,  Length of the list after filtering 41
#  key=SalesRevenueGoodsNet,  Length of the list final 41
# [   {   'accn': '0000950123-10-017258',
#         'end': '2007-12-31',
#         'filed': '2010-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2007',
#         'fy': 2009,
#         'start': '2007-01-01',
#         'val': 5171000000},
#     {   'accn': '0000950123-09-030883',
#         'end': '2008-06-30',
#         'filed': '2009-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2008Q2',
#         'fy': 2009,
#         'start': '2008-04-01',
#         'val': 1466000000},
#     {   'accn': '0000950123-09-058111',
#         'end': '2008-09-30',
#         'filed': '2009-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2008Q3',
#         'fy': 2009,
#         'start': '2008-07-01',
#         'val': 1446000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2008-12-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2008-01-01',
#         'val': 5734000000},
#     {   'accn': '0000950123-10-046646',
#         'end': '2009-03-31',
#         'filed': '2010-05-10',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2009Q1',
#         'fy': 2010,
#         'start': '2009-01-01',
#         'val': 1311000000},
#     {   'accn': '0000950123-10-074418',
#         'end': '2009-06-30',
#         'filed': '2010-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2009Q2',
#         'fy': 2010,
#         'start': '2009-04-01',
#         'val': 1156000000},
#     {   'accn': '0000950123-10-101816',
#         'end': '2009-09-30',
#         'filed': '2010-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2009Q3',
#         'fy': 2010,
#         'start': '2009-07-01',
#         'val': 1091000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2009-12-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2009',
#         'fy': 2011,
#         'start': '2009-01-01',
#         'val': 4809000000},
#     {   'accn': '0000950123-11-043927',
#         'end': '2010-03-31',
#         'filed': '2011-05-03',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2010Q1',
#         'fy': 2011,
#         'start': '2010-01-01',
#         'val': 1253000000},
#     {   'accn': '0000950123-11-071231',
#         'end': '2010-06-30',
#         'filed': '2011-08-02',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2010Q2',
#         'fy': 2011,
#         'start': '2010-04-01',
#         'val': 1357000000},
#     {   'accn': '0000950123-11-094428',
#         'end': '2010-09-30',
#         'filed': '2011-11-02',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2010Q3',
#         'fy': 2011,
#         'start': '2010-07-01',
#         'val': 1391000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2010-12-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010',
#         'fy': 2012,
#         'start': '2010-01-01',
#         'val': 5516000000},
#     {   'accn': '0001193125-12-201231',
#         'end': '2011-03-31',
#         'filed': '2012-05-01',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2011Q1',
#         'fy': 2012,
#         'start': '2011-01-01',
#         'val': 1433000000},
#     {   'accn': '0000808362-12-000013',
#         'end': '2011-06-30',
#         'filed': '2012-07-26',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2011Q2',
#         'fy': 2012,
#         'start': '2011-04-01',
#         'val': 1557000000},
#     {   'accn': '0000808362-12-000028',
#         'end': '2011-09-30',
#         'filed': '2012-10-24',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2011Q3',
#         'fy': 2012,
#         'start': '2011-07-01',
#         'val': 1663000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2011-12-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011',
#         'fy': 2013,
#         'start': '2011-01-01',
#         'val': 6382000000},
#     {   'accn': '0000808362-13-000038',
#         'end': '2012-03-31',
#         'filed': '2013-04-24',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2012Q1',
#         'fy': 2013,
#         'start': '2012-01-01',
#         'val': 1729000000},
#     {   'accn': '0000808362-13-000051',
#         'end': '2012-06-30',
#         'filed': '2013-07-24',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2012Q2',
#         'fy': 2013,
#         'start': '2012-04-01',
#         'val': 1811000000},
#     {   'accn': '0000808362-13-000061',
#         'end': '2012-09-30',
#         'filed': '2013-10-23',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2012Q3',
#         'fy': 2013,
#         'start': '2012-07-01',
#         'val': 1847000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2012-12-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012',
#         'fy': 2014,
#         'start': '2012-01-01',
#         'val': 7274000000},
#     {   'accn': '0000808362-14-000025',
#         'end': '2013-03-31',
#         'filed': '2014-04-23',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2013Q1',
#         'fy': 2014,
#         'start': '2013-01-01',
#         'val': 1749000000},
#     {   'accn': '0000808362-14-000041',
#         'end': '2013-06-30',
#         'filed': '2014-07-22',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2013Q2',
#         'fy': 2014,
#         'start': '2013-04-01',
#         'val': 1869000000},
#     {   'accn': '0000808362-14-000051',
#         'end': '2013-09-30',
#         'filed': '2014-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2013Q3',
#         'fy': 2014,
#         'start': '2013-07-01',
#         'val': 1936000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2013-12-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2013-01-01',
#         'val': 7594000000},
#     {   'accn': '0000808362-15-000018',
#         'end': '2014-03-31',
#         'filed': '2015-04-21',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2014Q1',
#         'fy': 2015,
#         'start': '2014-01-01',
#         'val': 1857000000},
#     {   'accn': '0000808362-15-000036',
#         'end': '2014-06-30',
#         'filed': '2015-07-23',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2014Q2',
#         'fy': 2015,
#         'start': '2014-04-01',
#         'val': 1975000000},
#     {   'accn': '0000808362-15-000043',
#         'end': '2014-09-30',
#         'filed': '2015-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2014Q3',
#         'fy': 2015,
#         'start': '2014-07-01',
#         'val': 2013000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2014-12-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2014',
#         'fy': 2016,
#         'start': '2014-01-01',
#         'val': 8056000000},
#     {   'accn': '0000808362-16-000069',
#         'end': '2015-03-31',
#         'filed': '2016-05-02',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2015Q1',
#         'fy': 2016,
#         'start': '2015-01-01',
#         'val': 1528000000},
#     {   'accn': '0000808362-16-000075',
#         'end': '2015-06-30',
#         'filed': '2016-07-29',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2015Q2',
#         'fy': 2016,
#         'start': '2015-04-01',
#         'val': 1431000000},
#     {   'accn': '0000808362-16-000089',
#         'end': '2015-09-30',
#         'filed': '2016-10-25',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2015Q3',
#         'fy': 2016,
#         'start': '2015-07-01',
#         'val': 1363000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2015-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015',
#         'fy': 2017,
#         'start': '2015-01-01',
#         'val': 12353000000},
#     {   'accn': '0000808362-17-000025',
#         'end': '2016-03-31',
#         'filed': '2017-04-28',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2016Q1',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 1013000000},
#     {   'accn': '0000808362-17-000034',
#         'end': '2016-06-30',
#         'filed': '2017-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2016Q2',
#         'fy': 2017,
#         'start': '2016-04-01',
#         'val': 954000000},
#     {   'accn': '0000808362-17-000037',
#         'end': '2016-09-30',
#         'filed': '2017-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2016Q3',
#         'fy': 2017,
#         'start': '2016-07-01',
#         'val': 2182000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 9488000000},
#     {   'accn': '0000808362-18-000012',
#         'end': '2017-03-31',
#         'filed': '2018-04-27',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2017Q1',
#         'fy': 2018,
#         'start': '2017-01-01',
#         'val': 2239000000},
#     {   'accn': '0000808362-17-000034',
#         'end': '2017-06-30',
#         'filed': '2017-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2017Q2',
#         'fy': 2017,
#         'start': '2017-04-01',
#         'val': 1002000000},
#     {   'accn': '0000808362-17-000037',
#         'end': '2017-09-30',
#         'filed': '2017-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2017Q3',
#         'fy': 2017,
#         'start': '2017-07-01',
#         'val': 3097000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2017-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017',
#         'fy': 2017,
#         'start': '2017-01-01',
#         'val': 10898000000},
#     {   'accn': '0000808362-18-000012',
#         'end': '2018-03-31',
#         'filed': '2018-04-27',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2018Q1',
#         'fy': 2018,
#         'start': '2018-01-01',
#         'val': 3160000000}]
#  key=SalesRevenueServicesNet,  Length of the list 117
#  key=SalesRevenueServicesNet,  Length of the list single filings 61
#  key=SalesRevenueServicesNet,  Length of the list after filtering 41
#  key=SalesRevenueServicesNet,  Length of the list final 41
# [   {   'accn': '0000950123-10-017258',
#         'end': '2007-12-31',
#         'filed': '2010-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2007',
#         'fy': 2009,
#         'start': '2007-01-01',
#         'val': 5257000000},
#     {   'accn': '0000950123-09-030883',
#         'end': '2008-06-30',
#         'filed': '2009-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2008Q2',
#         'fy': 2009,
#         'start': '2008-04-01',
#         'val': 1532000000},
#     {   'accn': '0000950123-09-058111',
#         'end': '2008-09-30',
#         'filed': '2009-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2008Q3',
#         'fy': 2009,
#         'start': '2008-07-01',
#         'val': 1564000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2008-12-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2008-01-01',
#         'val': 6130000000},
#     {   'accn': '0000950123-10-046646',
#         'end': '2009-03-31',
#         'filed': '2010-05-10',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2009Q1',
#         'fy': 2010,
#         'start': '2009-01-01',
#         'val': 1357000000},
#     {   'accn': '0000950123-10-074418',
#         'end': '2009-06-30',
#         'filed': '2010-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2009Q2',
#         'fy': 2010,
#         'start': '2009-04-01',
#         'val': 1180000000},
#     {   'accn': '0000950123-10-101816',
#         'end': '2009-09-30',
#         'filed': '2010-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2009Q3',
#         'fy': 2010,
#         'start': '2009-07-01',
#         'val': 1141000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2009-12-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2009',
#         'fy': 2011,
#         'start': '2009-01-01',
#         'val': 4855000000},
#     {   'accn': '0000950123-11-043927',
#         'end': '2010-03-31',
#         'filed': '2011-05-03',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2010Q1',
#         'fy': 2011,
#         'start': '2010-01-01',
#         'val': 1286000000},
#     {   'accn': '0000950123-11-071231',
#         'end': '2010-06-30',
#         'filed': '2011-08-02',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2010Q2',
#         'fy': 2011,
#         'start': '2010-04-01',
#         'val': 2017000000},
#     {   'accn': '0000950123-11-094428',
#         'end': '2010-09-30',
#         'filed': '2011-11-02',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2010Q3',
#         'fy': 2011,
#         'start': '2010-07-01',
#         'val': 2687000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2010-12-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010',
#         'fy': 2012,
#         'start': '2010-01-01',
#         'val': 8898000000},
#     {   'accn': '0001193125-12-201231',
#         'end': '2011-03-31',
#         'filed': '2012-05-01',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2011Q1',
#         'fy': 2012,
#         'start': '2011-01-01',
#         'val': 3092000000},
#     {   'accn': '0000808362-12-000013',
#         'end': '2011-06-30',
#         'filed': '2012-07-26',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2011Q2',
#         'fy': 2012,
#         'start': '2011-04-01',
#         'val': 3184000000},
#     {   'accn': '0000808362-12-000028',
#         'end': '2011-09-30',
#         'filed': '2012-10-24',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2011Q3',
#         'fy': 2012,
#         'start': '2011-07-01',
#         'val': 3401000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2011-12-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011',
#         'fy': 2013,
#         'start': '2011-01-01',
#         'val': 13449000000},
#     {   'accn': '0000808362-13-000038',
#         'end': '2012-03-31',
#         'filed': '2013-04-24',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2012Q1',
#         'fy': 2013,
#         'start': '2012-01-01',
#         'val': 3626000000},
#     {   'accn': '0000808362-13-000051',
#         'end': '2012-06-30',
#         'filed': '2013-07-24',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2012Q2',
#         'fy': 2013,
#         'start': '2012-04-01',
#         'val': 3515000000},
#     {   'accn': '0000808362-13-000061',
#         'end': '2012-09-30',
#         'filed': '2013-10-23',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2012Q3',
#         'fy': 2013,
#         'start': '2012-07-01',
#         'val': 3508000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2012-12-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012',
#         'fy': 2014,
#         'start': '2012-01-01',
#         'val': 14087000000},
#     {   'accn': '0000808362-14-000025',
#         'end': '2013-03-31',
#         'filed': '2014-04-23',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2013Q1',
#         'fy': 2014,
#         'start': '2013-01-01',
#         'val': 3481000000},
#     {   'accn': '0000808362-14-000041',
#         'end': '2013-06-30',
#         'filed': '2014-07-22',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2013Q2',
#         'fy': 2014,
#         'start': '2013-04-01',
#         'val': 3618000000},
#     {   'accn': '0000808362-14-000051',
#         'end': '2013-09-30',
#         'filed': '2014-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2013Q3',
#         'fy': 2014,
#         'start': '2013-07-01',
#         'val': 3851000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2013-12-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2013-01-01',
#         'val': 14770000000},
#     {   'accn': '0000808362-15-000018',
#         'end': '2014-03-31',
#         'filed': '2015-04-21',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2014Q1',
#         'fy': 2015,
#         'start': '2014-01-01',
#         'val': 3874000000},
#     {   'accn': '0000808362-15-000036',
#         'end': '2014-06-30',
#         'filed': '2015-07-23',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2014Q2',
#         'fy': 2015,
#         'start': '2014-04-01',
#         'val': 3960000000},
#     {   'accn': '0000808362-15-000043',
#         'end': '2014-09-30',
#         'filed': '2015-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2014Q3',
#         'fy': 2015,
#         'start': '2014-07-01',
#         'val': 4237000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2014-12-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2014',
#         'fy': 2016,
#         'start': '2014-01-01',
#         'val': 16495000000},
#     {   'accn': '0000808362-16-000069',
#         'end': '2015-03-31',
#         'filed': '2016-05-02',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2015Q1',
#         'fy': 2016,
#         'start': '2015-01-01',
#         'val': 3066000000},
#     {   'accn': '0000808362-16-000075',
#         'end': '2015-06-30',
#         'filed': '2016-07-29',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2015Q2',
#         'fy': 2016,
#         'start': '2015-04-01',
#         'val': 2537000000},
#     {   'accn': '0000808362-16-000089',
#         'end': '2015-09-30',
#         'filed': '2016-10-25',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2015Q3',
#         'fy': 2016,
#         'start': '2015-07-01',
#         'val': 2423000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2015-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015',
#         'fy': 2017,
#         'start': '2015-01-01',
#         'val': 4335000000},
#     {   'accn': '0000808362-17-000025',
#         'end': '2016-03-31',
#         'filed': '2017-04-28',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2016Q1',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 1657000000},
#     {   'accn': '0000808362-17-000034',
#         'end': '2016-06-30',
#         'filed': '2017-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2016Q2',
#         'fy': 2017,
#         'start': '2016-04-01',
#         'val': 1454000000},
#     {   'accn': '0000808362-17-000037',
#         'end': '2016-09-30',
#         'filed': '2017-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2016Q3',
#         'fy': 2017,
#         'start': '2016-07-01',
#         'val': 842000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 3781000000},
#     {   'accn': '0000808362-18-000012',
#         'end': '2017-03-31',
#         'filed': '2018-04-27',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2017Q1',
#         'fy': 2018,
#         'start': '2017-01-01',
#         'val': 825000000},
#     {   'accn': '0000808362-17-000034',
#         'end': '2017-06-30',
#         'filed': '2017-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2017Q2',
#         'fy': 2017,
#         'start': '2017-04-01',
#         'val': 1402000000},
#     {   'accn': '0000808362-17-000037',
#         'end': '2017-09-30',
#         'filed': '2017-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2017Q3',
#         'fy': 2017,
#         'start': '2017-07-01',
#         'val': 2278000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2017-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017',
#         'fy': 2017,
#         'start': '2017-01-01',
#         'val': 6361000000},
#     {   'accn': '0000808362-18-000012',
#         'end': '2018-03-31',
#         'filed': '2018-04-27',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2018Q1',
#         'fy': 2018,
#         'start': '2018-01-01',
#         'val': 2239000000}]
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list 8
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list single filings 8
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list after filtering 4
#  key=RevenueFromContractWithCustomerIncludingAssessedTax,  Length of the list final 4
# [   {   'accn': '0000808362-18-000017',
#         'end': '2017-06-30',
#         'filed': '2018-07-30',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2017Q2',
#         'fy': 2018,
#         'start': '2017-04-01',
#         'val': 3015000000},
#     {   'accn': '0000808362-18-000023',
#         'end': '2017-09-30',
#         'filed': '2018-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2017Q3',
#         'fy': 2018,
#         'start': '2017-07-01',
#         'val': 5301000000},
#     {   'accn': '0000808362-18-000017',
#         'end': '2018-06-30',
#         'filed': '2018-07-30',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2018Q2',
#         'fy': 2018,
#         'start': '2018-04-01',
#         'val': 5548000000},
#     {   'accn': '0000808362-18-000023',
#         'end': '2018-09-30',
#         'filed': '2018-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2018Q3',
#         'fy': 2018,
#         'start': '2018-07-01',
#         'val': 5665000000}]
#  key=GrossProfit,  Length of the list 100
#  key=GrossProfit,  Length of the list single filings 55
#  key=GrossProfit,  Length of the list after filtering 55
#  key=GrossProfit,  Length of the list final 55
# [   {   'accn': '0000950123-11-018883',
#         'end': '2009-03-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2009-01-01',
#         'val': 599000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2009-06-30',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2009-04-01',
#         'val': 437000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2009-09-30',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2009-07-01',
#         'val': 383000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2009-12-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2009-01-01',
#         'val': 1870000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2009-12-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2009-10-01',
#         'val': 451000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2010-03-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010Q1',
#         'fy': 2011,
#         'start': '2010-01-01',
#         'val': 533000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2010-06-30',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010Q2',
#         'fy': 2011,
#         'start': '2010-04-01',
#         'val': 600000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2010-09-30',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010Q3',
#         'fy': 2011,
#         'start': '2010-07-01',
#         'val': 771000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2010-12-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010',
#         'fy': 2011,
#         'start': '2010-01-01',
#         'val': 2801000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2010-12-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010Q4',
#         'fy': 2011,
#         'start': '2010-10-01',
#         'val': 897000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2011-03-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011Q1',
#         'fy': 2012,
#         'start': '2011-01-01',
#         'val': 922000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2011-06-30',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011Q2',
#         'fy': 2012,
#         'start': '2011-04-01',
#         'val': 909000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2011-09-30',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011Q3',
#         'fy': 2012,
#         'start': '2011-07-01',
#         'val': 1130000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2011-12-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011',
#         'fy': 2012,
#         'start': '2011-01-01',
#         'val': 4105000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2011-12-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011Q4',
#         'fy': 2012,
#         'start': '2011-10-01',
#         'val': 1144000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2012-03-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012Q1',
#         'fy': 2013,
#         'start': '2012-01-01',
#         'val': 966000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2012-06-30',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012Q2',
#         'fy': 2013,
#         'start': '2012-04-01',
#         'val': 944000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2012-09-30',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012Q3',
#         'fy': 2013,
#         'start': '2012-07-01',
#         'val': 841000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2012-12-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012',
#         'fy': 2013,
#         'start': '2012-01-01',
#         'val': 3508000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2012-12-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012Q4',
#         'fy': 2013,
#         'start': '2012-10-01',
#         'val': 757000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2013-03-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2013Q1',
#         'fy': 2014,
#         'start': '2013-01-01',
#         'val': 777000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2013-06-30',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2013Q2',
#         'fy': 2014,
#         'start': '2013-04-01',
#         'val': 765000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2013-09-30',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2013Q3',
#         'fy': 2014,
#         'start': '2013-07-01',
#         'val': 895000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2013-12-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2013',
#         'fy': 2014,
#         'start': '2013-01-01',
#         'val': 3255000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2013-12-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2013Q4',
#         'fy': 2014,
#         'start': '2013-10-01',
#         'val': 818000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2014-03-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2014-01-01',
#         'val': 868000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2014-06-30',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2014-04-01',
#         'val': 1031000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2014-09-30',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2014-07-01',
#         'val': 984000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2014-12-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2014-01-01',
#         'val': 4192000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2014-12-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2014-10-01',
#         'val': 1309000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2015-03-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015Q1',
#         'fy': 2016,
#         'start': '2015-01-01',
#         'val': 114000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2015-06-30',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015Q2',
#         'fy': 2016,
#         'start': '2015-04-01',
#         'val': 266000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2015-09-30',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015Q3',
#         'fy': 2016,
#         'start': '2015-07-01',
#         'val': 301000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2015-12-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015',
#         'fy': 2016,
#         'start': '2015-01-01',
#         'val': 861000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2015-12-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015Q4',
#         'fy': 2016,
#         'start': '2015-10-01',
#         'val': 180000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-03-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016Q1',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 798000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-06-30',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016Q2',
#         'fy': 2017,
#         'start': '2016-04-01',
#         'val': 785000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-09-30',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016Q3',
#         'fy': 2017,
#         'start': '2016-07-01',
#         'val': 730000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': 3146000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2016-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016Q4',
#         'fy': 2017,
#         'start': '2016-10-01',
#         'val': 833000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2017-03-31',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q1',
#         'fy': 2018,
#         'start': '2017-01-01',
#         'val': 687000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2017-06-30',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q2',
#         'fy': 2018,
#         'start': '2017-04-01',
#         'val': 539000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2017-09-30',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q3',
#         'fy': 2018,
#         'start': '2017-07-01',
#         'val': 952000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2017-12-31',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017',
#         'fy': 2018,
#         'start': '2017-01-01',
#         'val': 3036000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2017-12-31',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q4',
#         'fy': 2018,
#         'start': '2017-10-01',
#         'val': 858000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2018-03-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018Q1',
#         'fy': 2019,
#         'start': '2018-01-01',
#         'val': 841000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2018-06-30',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018Q2',
#         'fy': 2019,
#         'start': '2018-04-01',
#         'val': 936000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2018-09-30',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018Q3',
#         'fy': 2019,
#         'start': '2018-07-01',
#         'val': 973000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2018-12-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018',
#         'fy': 2019,
#         'start': '2018-01-01',
#         'val': 3986000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2018-12-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018Q4',
#         'fy': 2019,
#         'start': '2018-10-01',
#         'val': 1236000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2019-03-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q1',
#         'fy': 2019,
#         'start': '2019-01-01',
#         'val': 976000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2019-06-30',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q2',
#         'fy': 2019,
#         'start': '2019-04-01',
#         'val': 1062000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2019-09-30',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q3',
#         'fy': 2019,
#         'start': '2019-07-01',
#         'val': 1101000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2019-12-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019',
#         'fy': 2019,
#         'start': '2019-01-01',
#         'val': 4432000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2019-12-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q4',
#         'fy': 2019,
#         'start': '2019-10-01',
#         'val': 1295000000}]
#  key=OperatingIncomeLoss,  Length of the list 190
#  key=OperatingIncomeLoss,  Length of the list single filings 95
#  key=OperatingIncomeLoss,  Length of the list after filtering 63
#  key=OperatingIncomeLoss,  Length of the list final 63
# [   {   'accn': '0000950123-10-017258',
#         'end': '2007-12-31',
#         'filed': '2010-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2007',
#         'fy': 2009,
#         'start': '2007-01-01',
#         'val': 2278000000},
#     {   'accn': '0000950123-09-030883',
#         'end': '2008-06-30',
#         'filed': '2009-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2008Q2',
#         'fy': 2009,
#         'start': '2008-04-01',
#         'val': 563000000},
#     {   'accn': '0000950123-09-058111',
#         'end': '2008-09-30',
#         'filed': '2009-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2008Q3',
#         'fy': 2009,
#         'start': '2008-07-01',
#         'val': 601000000},
#     {   'accn': '0000950123-11-018883',
#         'end': '2008-12-31',
#         'filed': '2011-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2010,
#         'start': '2008-01-01',
#         'val': 2376000000},
#     {   'accn': '0000950123-10-046646',
#         'end': '2009-03-31',
#         'filed': '2010-05-10',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2009Q1',
#         'fy': 2010,
#         'start': '2009-01-01',
#         'val': 318000000},
#     {   'accn': '0000950123-10-074418',
#         'end': '2009-06-30',
#         'filed': '2010-08-06',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2009Q2',
#         'fy': 2010,
#         'start': '2009-04-01',
#         'val': 153000000},
#     {   'accn': '0000950123-10-101816',
#         'end': '2009-09-30',
#         'filed': '2010-11-05',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2009Q3',
#         'fy': 2010,
#         'start': '2009-07-01',
#         'val': 111000000},
#     {   'accn': '0001193125-12-078521',
#         'end': '2009-12-31',
#         'filed': '2012-02-24',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2009',
#         'fy': 2011,
#         'start': '2009-01-01',
#         'val': 732000000},
#     {   'accn': '0000950123-11-043927',
#         'end': '2010-03-31',
#         'filed': '2011-05-03',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2010Q1',
#         'fy': 2011,
#         'start': '2010-01-01',
#         'val': 218000000},
#     {   'accn': '0000950123-11-071231',
#         'end': '2010-06-30',
#         'filed': '2011-08-02',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2010Q2',
#         'fy': 2011,
#         'start': '2010-04-01',
#         'val': 232000000},
#     {   'accn': '0000950123-11-094428',
#         'end': '2010-09-30',
#         'filed': '2011-11-02',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2010Q3',
#         'fy': 2011,
#         'start': '2010-07-01',
#         'val': 405000000},
#     {   'accn': '0000808362-13-000017',
#         'end': '2010-12-31',
#         'filed': '2013-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2010',
#         'fy': 2012,
#         'start': '2010-01-01',
#         'val': 1417000000},
#     {   'accn': '0001193125-12-201231',
#         'end': '2011-03-31',
#         'filed': '2012-05-01',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2011Q1',
#         'fy': 2012,
#         'start': '2011-01-01',
#         'val': 640000000},
#     {   'accn': '0000808362-12-000013',
#         'end': '2011-06-30',
#         'filed': '2012-07-26',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2011Q2',
#         'fy': 2012,
#         'start': '2011-04-01',
#         'val': 617000000},
#     {   'accn': '0000808362-12-000028',
#         'end': '2011-09-30',
#         'filed': '2012-10-24',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2011Q3',
#         'fy': 2012,
#         'start': '2011-07-01',
#         'val': 805000000},
#     {   'accn': '0000808362-14-000007',
#         'end': '2011-12-31',
#         'filed': '2014-02-12',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2011',
#         'fy': 2013,
#         'start': '2011-01-01',
#         'val': 2600000000},
#     {   'accn': '0000808362-13-000038',
#         'end': '2012-03-31',
#         'filed': '2013-04-24',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2012Q1',
#         'fy': 2013,
#         'start': '2012-01-01',
#         'val': 627000000},
#     {   'accn': '0000808362-13-000051',
#         'end': '2012-06-30',
#         'filed': '2013-07-24',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2012Q2',
#         'fy': 2013,
#         'start': '2012-04-01',
#         'val': 639000000},
#     {   'accn': '0000808362-13-000061',
#         'end': '2012-09-30',
#         'filed': '2013-10-23',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2012Q3',
#         'fy': 2013,
#         'start': '2012-07-01',
#         'val': 486000000},
#     {   'accn': '0000808362-15-000006',
#         'end': '2012-12-31',
#         'filed': '2015-02-26',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2012',
#         'fy': 2014,
#         'start': '2012-01-01',
#         'val': 2192000000},
#     {   'accn': '0000808362-14-000025',
#         'end': '2013-03-31',
#         'filed': '2014-04-23',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2013Q1',
#         'fy': 2014,
#         'start': '2013-01-01',
#         'val': 455000000},
#     {   'accn': '0000808362-14-000041',
#         'end': '2013-06-30',
#         'filed': '2014-07-22',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2013Q2',
#         'fy': 2014,
#         'start': '2013-04-01',
#         'val': 436000000},
#     {   'accn': '0000808362-14-000051',
#         'end': '2013-09-30',
#         'filed': '2014-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2013Q3',
#         'fy': 2014,
#         'start': '2013-07-01',
#         'val': 576000000},
#     {   'accn': '0000808362-16-000053',
#         'end': '2013-12-31',
#         'filed': '2016-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'start': '2013-01-01',
#         'val': 1949000000},
#     {   'accn': '0000808362-15-000018',
#         'end': '2014-03-31',
#         'filed': '2015-04-21',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2014Q1',
#         'fy': 2015,
#         'start': '2014-01-01',
#         'val': 552000000},
#     {   'accn': '0000808362-15-000036',
#         'end': '2014-06-30',
#         'filed': '2015-07-23',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2014Q2',
#         'fy': 2015,
#         'start': '2014-04-01',
#         'val': 631000000},
#     {   'accn': '0000808362-15-000043',
#         'end': '2014-09-30',
#         'filed': '2015-10-21',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2014Q3',
#         'fy': 2015,
#         'start': '2014-07-01',
#         'val': 661000000},
#     {   'accn': '0000808362-17-000006',
#         'end': '2014-12-31',
#         'filed': '2017-02-08',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2014',
#         'fy': 2016,
#         'start': '2014-01-01',
#         'val': 2859000000},
#     {   'accn': '0000808362-16-000069',
#         'end': '2015-03-31',
#         'filed': '2016-05-02',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2015Q1',
#         'fy': 2016,
#         'start': '2015-01-01',
#         'val': -774000000},
#     {   'accn': '0000808362-16-000075',
#         'end': '2015-06-30',
#         'filed': '2016-07-29',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2015Q2',
#         'fy': 2016,
#         'start': '2015-04-01',
#         'val': -144000000},
#     {   'accn': '0000808362-16-000089',
#         'end': '2015-09-30',
#         'filed': '2016-10-25',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2015Q3',
#         'fy': 2016,
#         'start': '2015-07-01',
#         'val': -101000000},
#     {   'accn': '0000808362-18-000006',
#         'end': '2015-12-31',
#         'filed': '2018-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015',
#         'fy': 2017,
#         'start': '2015-01-01',
#         'val': -138000000},
#     {   'accn': '0000808362-17-000025',
#         'end': '2016-03-31',
#         'filed': '2017-04-28',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2016Q1',
#         'fy': 2017,
#         'start': '2016-01-01',
#         'val': -559000000},
#     {   'accn': '0000808362-17-000034',
#         'end': '2016-06-30',
#         'filed': '2017-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2016Q2',
#         'fy': 2017,
#         'start': '2016-04-01',
#         'val': -570000000},
#     {   'accn': '0000808362-17-000037',
#         'end': '2016-09-30',
#         'filed': '2017-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2016Q3',
#         'fy': 2017,
#         'start': '2016-07-01',
#         'val': 176000000},
#     {   'accn': '0000808362-19-000006',
#         'end': '2016-12-31',
#         'filed': '2019-02-19',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016',
#         'fy': 2018,
#         'start': '2016-01-01',
#         'val': 457000000},
#     {   'accn': '0000808362-18-000012',
#         'end': '2017-03-31',
#         'filed': '2018-04-27',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2017Q1',
#         'fy': 2018,
#         'start': '2017-01-01',
#         'val': 86000000},
#     {   'accn': '0000808362-18-000017',
#         'end': '2017-06-30',
#         'filed': '2018-07-30',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2017Q2',
#         'fy': 2018,
#         'start': '2017-04-01',
#         'val': -66000000},
#     {   'accn': '0000808362-18-000023',
#         'end': '2017-09-30',
#         'filed': '2018-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2017Q3',
#         'fy': 2018,
#         'start': '2017-07-01',
#         'val': -193000000},
#     {   'accn': '0000808362-20-000003',
#         'end': '2017-12-31',
#         'filed': '2020-02-13',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017',
#         'fy': 2019,
#         'start': '2017-01-01',
#         'val': -284000000},
#     {   'accn': '0000808362-19-000011',
#         'end': '2018-03-31',
#         'filed': '2019-04-30',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2018Q1',
#         'fy': 2019,
#         'start': '2018-01-01',
#         'val': -41000000},
#     {   'accn': '0000808362-19-000016',
#         'end': '2018-06-30',
#         'filed': '2019-08-01',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2018Q2',
#         'fy': 2019,
#         'start': '2018-04-01',
#         'val': 78000000},
#     {   'accn': '0000808362-19-000019',
#         'end': '2018-09-30',
#         'filed': '2019-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2018Q3',
#         'fy': 2019,
#         'start': '2018-07-01',
#         'val': 282000000},
#     {   'accn': '0000808362-21-000004',
#         'end': '2018-12-31',
#         'filed': '2021-02-25',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018',
#         'fy': 2020,
#         'start': '2018-01-01',
#         'val': 701000000},
#     {   'accn': '0000808362-20-000009',
#         'end': '2019-03-31',
#         'filed': '2020-04-24',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2019Q1',
#         'fy': 2020,
#         'start': '2019-01-01',
#         'val': 176000000},
#     {   'accn': '0000808362-20-000012',
#         'end': '2019-06-30',
#         'filed': '2020-07-24',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2019Q2',
#         'fy': 2020,
#         'start': '2019-04-01',
#         'val': 271000000},
#     {   'accn': '0000808362-20-000014',
#         'end': '2019-09-30',
# ...
#         'start': '2017-12-31',
#         'val': 1284000000},
#     {   'accn': '0001637459-20-000061',
#         'end': '2019-03-30',
#         'filed': '2020-05-01',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2019Q1',
#         'fy': 2020,
#         'start': '2018-12-30',
#         'val': 321000000},
#     {   'accn': '0001637459-20-000131',
#         'end': '2019-06-29',
#         'filed': '2020-07-31',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'fy': 2020,
#         'start': '2018-12-30',
#         'val': 637000000},
#     {   'accn': '0001637459-20-000159',
#         'end': '2019-09-28',
#         'filed': '2020-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'fy': 2020,
#         'start': '2018-12-30',
#         'val': 1035000000},
#     {   'accn': '0001637459-22-000018',
#         'end': '2019-12-28',
#         'filed': '2022-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019',
#         'fy': 2021,
#         'start': '2018-12-30',
#         'val': 1361000000},
#     {   'accn': '0001637459-21-000047',
#         'end': '2020-03-28',
#         'filed': '2021-04-30',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2020Q1',
#         'fy': 2021,
#         'start': '2019-12-29',
#         'val': 310000000},
#     {   'accn': '0001637459-21-000099',
#         'end': '2020-06-27',
#         'filed': '2021-08-04',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'fy': 2021,
#         'start': '2019-12-29',
#         'val': 752000000},
#     {   'accn': '0001637459-21-000127',
#         'end': '2020-09-26',
#         'filed': '2021-10-28',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'fy': 2021,
#         'start': '2019-12-29',
#         'val': 1066000000},
#     {   'accn': '0001637459-23-000009',
#         'end': '2020-12-26',
#         'filed': '2023-02-16',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2020',
#         'fy': 2022,
#         'start': '2019-12-29',
#         'val': 1394000000},
#     {   'accn': '0001637459-22-000060',
#         'end': '2021-03-27',
#         'filed': '2022-04-28',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2021Q1',
#         'fy': 2022,
#         'start': '2020-12-27',
#         'val': 415000000},
#     {   'accn': '0001637459-22-000159',
#         'end': '2021-06-26',
#         'filed': '2022-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'fy': 2022,
#         'start': '2020-12-27',
#         'val': 1028000000},
#     {   'accn': '0001637459-22-000191',
#         'end': '2021-09-25',
#         'filed': '2022-10-27',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'fy': 2022,
#         'start': '2020-12-27',
#         'val': 1443000000},
#     {   'accn': '0001637459-24-000018',
#         'end': '2021-12-25',
#         'filed': '2024-02-15',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2021',
#         'fy': 2023,
#         'start': '2020-12-27',
#         'val': 2047000000},
#     {   'accn': '0001637459-23-000047',
#         'end': '2022-03-26',
#         'filed': '2023-05-03',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2022Q1',
#         'fy': 2022,
#         'start': '2021-12-26',
#         'val': 242000000},
#     {   'accn': '0001637459-23-000114',
#         'end': '2022-06-25',
#         'filed': '2023-08-02',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'fy': 2023,
#         'start': '2021-12-26',
#         'val': 476000000},
#     {   'accn': '0001637459-23-000143',
#         'end': '2022-09-24',
#         'filed': '2023-11-01',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'fy': 2023,
#         'start': '2021-12-26',
#         'val': 704000000},
#     {   'accn': '0001637459-24-000018',
#         'end': '2022-12-31',
#         'filed': '2024-02-15',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2022',
#         'fy': 2023,
#         'start': '2021-12-26',
#         'val': 921000000},
#     {   'accn': '0001637459-23-000143',
#         'end': '2023-09-30',
#         'filed': '2023-11-01',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2023Q3',
#         'fy': 2023,
#         'start': '2023-07-02',
#         'val': 228000000},
#     {   'accn': '0001637459-24-000018',
#         'end': '2023-12-30',
#         'filed': '2024-02-15',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2023',
#         'fy': 2023,
#         'start': '2023-01-01',
#         'val': 912000000}]
#  key=LeaseAndRentalExpense,  Length of the list 0
#  key=LeaseAndRentalExpense,  Length of the list single filings 0
#  key=LeaseAndRentalExpense,  Length of the list after filtering 0
#  key=LeaseAndRentalExpense,  Length of the list final 0
# []
#  key=MarketingAndAdvertisingExpense,  Length of the list 9
#  key=MarketingAndAdvertisingExpense,  Length of the list single filings 5
#  key=MarketingAndAdvertisingExpense,  Length of the list after filtering 5
#  key=MarketingAndAdvertisingExpense,  Length of the list final 5
# [   {   'accn': '0001637459-19-000049',
#         'end': '2016-12-31',
#         'filed': '2019-06-07',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016',
#         'fy': 2018,
#         'start': '2016-01-04',
#         'val': 1221000000},
#     {   'accn': '0001637459-20-000027',
#         'end': '2017-12-30',
#         'filed': '2020-02-14',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2019,
#         'start': '2017-01-01',
#         'val': 1100000000},
#     {   'accn': '0001637459-21-000009',
#         'end': '2018-12-29',
#         'filed': '2021-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018',
#         'fy': 2020,
#         'start': '2017-12-31',
#         'val': 1100000000},
#     {   'accn': '0001637459-21-000009',
#         'end': '2019-12-28',
#         'filed': '2021-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019',
#         'fy': 2020,
#         'start': '2018-12-30',
#         'val': 1100000000},
#     {   'accn': '0001637459-21-000009',
#         'end': '2020-12-26',
#         'filed': '2021-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2020',
#         'fy': 2020,
#         'start': '2019-12-29',
#         'val': 1200000000}]
#  key=EntityCommonStockSharesOutstanding,  Length of the list 35
#  key=EntityCommonStockSharesOutstanding,  Length of the list single filings 34
#  key=EntityCommonStockSharesOutstanding,  Length of the list after filtering 0
#  key=EntityCommonStockSharesOutstanding,  Length of the list final 34
# [   {   'accn': '0001637459-15-000021',
#         'end': '2015-08-02',
#         'filed': '2015-08-10',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2015Q2I',
#         'fy': 2015,
#         'val': 1212833289},
#     {   'accn': '0001637459-15-000049',
#         'end': '2015-11-01',
#         'filed': '2015-11-06',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2015Q3I',
#         'fy': 2015,
#         'val': 1213455716},
#     {   'accn': '0001637459-16-000100',
#         'end': '2016-02-28',
#         'filed': '2016-03-03',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2015,
#         'val': 1215189526},
#     {   'accn': '0001637459-16-000147',
#         'end': '2016-05-01',
#         'filed': '2016-05-05',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2016Q1I',
#         'fy': 2016,
#         'val': 1215955228},
#     {   'accn': '0001637459-16-000179',
#         'end': '2016-07-31',
#         'filed': '2016-08-05',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2016Q2I',
#         'fy': 2016,
#         'val': 1217650866},
#     {   'accn': '0001637459-16-000207',
#         'end': '2016-10-30',
#         'filed': '2016-11-04',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2016Q3I',
#         'fy': 2016,
#         'val': 1217270219},
#     {   'accn': '0001637459-17-000007',
#         'end': '2017-02-18',
#         'filed': '2017-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'fy': 2016,
#         'val': 1217136057},
#     {   'accn': '0001637459-17-000081',
#         'end': '2017-04-29',
#         'filed': '2017-05-04',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'fy': 2017,
#         'val': 1217633003},
#     {   'accn': '0001637459-17-000101',
#         'end': '2017-07-29',
#         'filed': '2017-08-04',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'fy': 2017,
#         'val': 1218251122},
#     {   'accn': '0001637459-17-000118',
#         'end': '2017-10-28',
#         'filed': '2017-11-07',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2017Q3I',
#         'fy': 2017,
#         'val': 1218467836},
#     {   'accn': '0001637459-18-000015',
#         'end': '2018-02-10',
#         'filed': '2018-02-16',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q4I',
#         'fy': 2017,
#         'val': 1218801890},
#     {   'accn': '0001637459-18-000099',
#         'end': '2018-04-28',
#         'filed': '2018-05-03',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2018Q1I',
#         'fy': 2018,
#         'val': 1219172261},
#     {   'accn': '0001637459-18-000116',
#         'end': '2018-07-28',
#         'filed': '2018-08-03',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2018Q2I',
#         'fy': 2018,
#         'val': 1219248231},
#     {   'accn': '0001637459-18-000124',
#         'end': '2018-10-27',
#         'filed': '2018-11-02',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2018Q3I',
#         'fy': 2018,
#         'val': 1219434812},
#     {   'accn': '0001637459-19-000049',
#         'end': '2019-06-05',
#         'filed': '2019-06-07',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q2I',
#         'fy': 2018,
#         'val': 1219938804},
#     {   'accn': '0001637459-19-000072',
#         'end': '2019-08-03',
#         'filed': '2019-08-13',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'fy': 2019,
#         'val': 1219991425},
#     {   'accn': '0001637459-19-000113',
#         'end': '2019-10-26',
#         'filed': '2019-10-31',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2019Q3I',
#         'fy': 2019,
#         'val': 1221160646},
#     {   'accn': '0001637459-20-000027',
#         'end': '2020-02-08',
#         'filed': '2020-02-14',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q4I',
#         'fy': 2019,
#         'val': 1221399549},
#     {   'accn': '0001637459-20-000061',
#         'end': '2020-04-25',
#         'filed': '2020-05-01',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2020Q1I',
#         'fy': 2020,
#         'val': 1221833078},
#     {   'accn': '0001637459-20-000131',
#         'end': '2020-07-25',
#         'filed': '2020-07-31',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2020Q2I',
#         'fy': 2020,
#         'val': 1222578592},
#     {   'accn': '0001637459-20-000159',
#         'end': '2020-10-24',
#         'filed': '2020-10-30',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2020Q3I',
#         'fy': 2020,
#         'val': 1222623168},
#     {   'accn': '0001637459-21-000009',
#         'end': '2021-02-13',
#         'filed': '2021-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2020Q4I',
#         'fy': 2020,
#         'val': 1223175747},
#     {   'accn': '0001637459-21-000047',
#         'end': '2021-04-24',
#         'filed': '2021-04-30',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2021Q1I',
#         'fy': 2021,
#         'val': 1223147340},
#     {   'accn': '0001637459-21-000099',
#         'end': '2021-07-31',
#         'filed': '2021-08-04',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2021Q2I',
#         'fy': 2021,
#         'val': 1223387136},
#     {   'accn': '0001637459-21-000127',
#         'end': '2021-10-23',
#         'filed': '2021-10-28',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2021Q3I',
#         'fy': 2021,
#         'val': 1225261485},
#     {   'accn': '0001637459-22-000018',
#         'end': '2022-02-12',
#         'filed': '2022-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2021Q4I',
#         'fy': 2021,
#         'val': 1223740203},
#     {   'accn': '0001637459-22-000060',
#         'end': '2022-04-23',
#         'filed': '2022-04-28',
#         'form': '10-Q',
#         'fp': 'Q1',
#         'frame': 'CY2022Q1I',
#         'fy': 2022,
#         'val': 1223951939},
#     {   'accn': '0001637459-22-000159',
#         'end': '2022-07-23',
#         'filed': '2022-07-28',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2022Q2I',
#         'fy': 2022,
#         'val': 1225439747},
#     {   'accn': '0001637459-22-000191',
#         'end': '2022-10-22',
#         'filed': '2022-10-27',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2022Q3I',
#         'fy': 2022,
#         'val': 1224930164},
#     {   'accn': '0001637459-23-000009',
#         'end': '2023-02-11',
#         'filed': '2023-02-16',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2022Q4I',
#         'fy': 2022,
#         'val': 1225003377},
#     {   'accn': '0001637459-23-000047',
#         'end': '2023-04-29',
#         'filed': '2023-05-03',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2023Q1I',
#         'fy': 2022,
#         'val': 1227237484},
#     {   'accn': '0001637459-23-000114',
#         'end': '2023-07-29',
#         'filed': '2023-08-02',
#         'form': '10-Q',
#         'fp': 'Q2',
#         'frame': 'CY2023Q2I',
#         'fy': 2023,
#         'val': 1228294502},
#     {   'accn': '0001637459-23-000143',
#         'end': '2023-10-28',
#         'filed': '2023-11-01',
#         'form': '10-Q',
#         'fp': 'Q3',
#         'frame': 'CY2023Q3I',
#         'fy': 2023,
#         'val': 1226538694},
#     {   'accn': '0001637459-24-000018',
#         'end': '2024-02-10',
#         'filed': '2024-02-15',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2023Q4I',
#         'fy': 2023,
#         'val': 1213099787}]
#  key=EntityPublicFloat,  Length of the list 9
#  key=EntityPublicFloat,  Length of the list single filings 9
#  key=EntityPublicFloat,  Length of the list after filtering 0
#  key=EntityPublicFloat,  Length of the list final 9
# [   {   'accn': '0001637459-16-000100',
#         'end': '2015-06-26',
#         'filed': '2016-03-03',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2015Q2I',
#         'fy': 2015,
#         'val': 0},
#     {   'accn': '0001637459-17-000007',
#         'end': '2016-07-01',
#         'filed': '2017-02-23',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2016Q2I',
#         'fy': 2016,
#         'val': 107000000000},
#     {   'accn': '0001637459-18-000015',
#         'end': '2017-07-01',
#         'filed': '2018-02-16',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2017Q2I',
#         'fy': 2017,
#         'val': 52000000000},
#     {   'accn': '0001637459-19-000049',
#         'end': '2018-06-30',
#         'filed': '2019-06-07',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2018Q2I',
#         'fy': 2018,
#         'val': 38000000000},
#     {   'accn': '0001637459-20-000027',
#         'end': '2019-06-29',
#         'filed': '2020-02-14',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2019Q2I',
#         'fy': 2019,
#         'val': 19000000000},
#     {   'accn': '0001637459-21-000009',
#         'end': '2020-06-26',
#         'filed': '2021-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2020Q2I',
#         'fy': 2020,
#         'val': 20000000000},
#     {   'accn': '0001637459-22-000018',
#         'end': '2021-06-25',
#         'filed': '2022-02-17',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2021Q2I',
#         'fy': 2021,
#         'val': 28000000000},
#     {   'accn': '0001637459-23-000009',
#         'end': '2022-06-24',
#         'filed': '2023-02-16',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2022Q2I',
#         'fy': 2022,
#         'val': 34600000000},
#     {   'accn': '0001637459-24-000018',
#         'end': '2023-07-01',
#         'filed': '2024-02-15',
#         'form': '10-K',
#         'fp': 'FY',
#         'frame': 'CY2023Q2I',
#         'fy': 2023,
#         'val': 32100000000}]
